# %% [markdown]
# **STARTING WITH SELF-SUPERVISED LEARNING**

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # Packages

# %%
# # Essential libraries.
import matplotlib.pyplot as plt
# import numpy as np
# import seaborn as sns
# import os
import tensorflow as tf
# import pandas as pd
# import dataframe_image as dfi

# # Modules.
# import tensorflow.keras.layers as tfl
# from tensorflow.keras.utils import image_dataset_from_directory
# from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
# from sklearn.metrics import classification_report

# # Information.
# print(tf.__version__)
# # os.environ["CUDA_VISIBLE_DEVICES"] = '-1'    # Disable GPU.
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# # Set seed.
# np.random.seed(42)
# tf.random.set_seed(42)

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # Dataset

# %%
import lulc

# %%
# Dataset info.
split_train_val = 0.3
shuffle = True
train_dataset, validation_dataset, test_dataset = lulc.tf_data_loader()
# Out:
# 2.9.1
# Num GPUs Available:  1
# 2022-10-17 14:16:07.598366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 14:16:07.603803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 14:16:07.604144: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Found 194877 files belonging to 29 classes.
# Using 136414 files for training.
# 2022-10-17 14:16:15.892766: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-17 14:16:15.893477: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 14:16:15.893731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 14:16:15.893879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 14:16:16.286103: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 14:16:16.286244: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 14:16:16.286344: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 14:16:16.286431: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1009 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 194877 files belonging to 29 classes.
# Using 58463 files for validation.
# Classes:  ['01_BarrenLands___jpeg', '02_MossAndLichen_jpeg', '03_Grasslands____jpeg', '04_ShrublandOpen_jpeg', '05_SrublandClose_jpeg', '06_ForestsOpDeBr_jpeg', '07_ForestsClDeBr_jpeg', '08_ForestsDeDeBr_jpeg', '09_ForestsOpDeNe_jpeg', '10_ForestsClDeNe_jpeg', '11_ForestsDeDeNe_jpeg', '12_ForestsOpEvBr_jpeg', '13_ForestsClEvBr_jpeg', '14_ForestsDeEvBr_jpeg', '15_ForestsOpEvNe_jpeg', '16_ForestsClEvNe_jpeg', '17_ForestsDeEvNe_jpeg', '18_WetlandMangro_jpeg', '19_WetlandSwamps_jpeg', '20_WetlandMarshl_jpeg', '21_WaterBodyMari_jpeg', '22_WaterBodyCont_jpeg', '23_PermanentSnow_jpeg', '24_CropSeasWater_jpeg', '25_CropCereaIrri_jpeg', '26_CropCereaRain_jpeg', '27_CropBroadIrri_jpeg', '28_CropBroadRain_jpeg', '29_UrbanBlUpArea_jpeg']
# Number of classes:  29
# Training batches: 4263
# Training samples: 136416 (70.0%)
#
# Validation batches: 609
# Validation samples: 19488 (10.0%)
#
# Test batches: 1218
# Test samples: 38976 (20.0%)
#
# Total approx.: 194880

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # SSL
